# %%
#intializing list of lists
menu = []
menu_item = []
menu_category = []
menu_description = []
menu_price = []
menu_cost = []
line_item = []
date = []
credit_card = []
quantity = []
menu_two = []

report[dict]={}


with open (csvpath_one, "r") as csvfile:

    csvreader = csv.reader(csvfile, delimiter = ",")
  
    csv_header = next(csvreader)
    
    #item = ""
    #category = ""
    #description = ""
    #price = 0
    #cost = 0
    
    #helper.make_list(csvreader, item, category, description, 
                       #price, cost, menu_item, menu_category, menu_description, menu_price, menu_cost)
    for row in csvreader:
        item = row[0]
        category = row[1]
        description = row[2]
        price = row[3]
        cost = row[4]
        
        menu_item.append(item)
        menu_category.append(category)
        menu_description.append(description)
        menu_price.append(price)
        menu_cost.append(cost)
    
    
    menu = [[menu_item], [menu_category], [menu_description], [menu_price], [menu_cost]]
    #print(menu)
    
with open (csvpath_two, "r") as csvfile_two:
    
    csvreader_two = csv.reader(csvfile_two, delimiter = ",")
    
    csvheader_two = next(csvreader_two)
    
    #number_sales= ""
    #date_sales = ""
    #card_sales = ""
    #quantity_sales = ""
    #menu_sales = ""
    
    #helper.make_list(csvreader_two, number_sales, date_sales, card_sales, 
                     #quantity_sales, menu_sales, line_item, date, credit_card, quantity, menu_two)
    for row in csvreader_two:
        number_sales = row[0]
        date_sales = row[1]
        card_sales = row[2]
        quantity_sales = row[3]
        menu_sales = row[4]
        
        line_item.append(number_sales)
        date.append(date_sales)
        credit_card.append(card_sales)
        quantity.append(quantity_sales)
        menu_two.append(menu_sales)
        
        item_menu = []
        item_quantity = []
        count = 0 
        previous_quantity = 0
        
    for menu_sales  in menu_two:
        if menu_sales not in item_menu:
            item_menu.append(menu_sales)
            
            report[dict]= dict.fromkeys(item_menu)
    
    
    
    #for row in csvreader_two:
